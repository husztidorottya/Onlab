# %%
import sys
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import nltk
from wordcloud import WordCloud, STOPWORDS

# set plot properties
matplotlib.style.use('ggplot')
matplotlib.pyplot.rcParams['figure.figsize'] = (25, 13)
matplotlib.pyplot.rcParams['font.family'] = 'sans-serif'
matplotlib.pyplot.rcParams['font.size'] = 20

# read the experiment result
df = pd.read_csv('log_experiment.csv')

# visualize the score according to the average of embeddingDim
df.groupby(by=[df.embedding]).mean().plot(y='score', kind='bar', color='blue')

# show table grouped by embeddingDim
columns = ['score']
df_embedding = df[columns]
df_embedding.groupby(by=[df.embedding]).mean()
# Out:
#               score
# embedding
# 1          0.844301
# 10         0.845231
# 20         0.842031
# 30         0.842519
# 40         0.843274
# 50         0.846829

# %%
# visualize the score according to the average of LSTM cells
df.groupby(by=[df.LSTM]).mean().plot(y='score', kind='bar')

# show table grouped by LSTM cells
df_LSTM = df[columns]
df_LSTM.groupby(by=[df.LSTM]).mean()
# Out:
#          score
# LSTM
# 2     0.816270
# 4     0.849289
# 8     0.850361
# 16    0.861168
# 32    0.853129
# 64    0.842447
# 128   0.849547
# 256   0.835433
# 512   0.835597

# %%
# visualize the score according to the average of batch size
df.groupby(by=[df.batch]).mean().plot(y='score', kind='bar', color='green')

# show table grouped by batch size
df_batch = df[columns]
df_batch.groupby(by=[df.batch]).mean()
# Out:
#           score
# batch
# 2      0.846937
# 4      0.848409
# 8      0.846331
# 16     0.843999
# 32     0.845521
# 64     0.845609
# 128    0.836457
# 256    0.837389
# 512    0.845068

# %%
# visualize the score according to the average of character number
df.groupby(by=[df.charnum]).mean().plot(y='score', kind='bar', color='pink')

# show table grouped by character number
columns = ['score']
df_embedding = df[columns]
df_embedding.groupby(by=[df.charnum]).mean()
# Out:
#             score
# charnum
# 1        0.831986
# 2        0.823542
# 3        0.832557
# 4        0.840973
# 5        0.843033
# 6        0.844489
# 7        0.852201
# 8        0.857945
# 9        0.854547
# 10       0.861165

# %%
# visualize the score according to the average of character direction
df.groupby(by=[df.chardir]).mean().plot(y='score', kind='bar', color='purple')

# show table grouped by character direction
columns = ['score']
df_embedding = df[columns]
df_embedding.groupby(by=[df.chardir]).mean()
# Out:
#             score
# chardir
# 0        0.795532
# 1        0.891848

# %%
# visualize the score according to the average of ngrams enabled
df.groupby(by=[df.ngramson]).mean().plot(y='score', kind='bar', color='yellow')

# show table grouped by ngrams enabled
columns = ['score']
df_embedding = df[columns]
df_embedding.groupby(by=[df.ngramson]).mean()
# Out:
#              score
# ngramson
# 0         0.850307
# 1         0.837712

# %%
# visualize the score according to the average of ngrams n
df.groupby(by=[df.ngramsn]).mean().plot(y='score', kind='bar', color='red')

# show table grouped by ngrams n
columns = ['score']
df_embedding = df[columns]
df_embedding.groupby(by=[df.ngramsn]).mean()
# Out:
#             score
# ngramsn
# 1        0.836872
# 2        0.845643
# 3        0.849433
